# %%
import pandas as pd
df=pd.read_csv('Network_Data/hourly_data.csv')

# %%
df.describe()
# Out:
#        Temperature (°C)  Humidity (%)  Wind Speed (m/s)  Rainfall (mm)  \
# count      47472.000000  47472.000000      47472.000000   47472.000000
# mean          28.001544     79.998447          1.996106      20.056869
# std            1.001721      2.495015          0.500841      10.056056
# min           23.643244     69.903926          0.030375       0.709915
# 25%           27.323114     78.306814          1.659619      12.675970
# 50%           27.997249     79.983101          1.997537      18.378588
# 75%           28.676152     81.669268          2.332365      25.594933
# max           32.011171     89.933493          4.015965      85.381109
#
#        Solar Irradiance (W/m²)     GDP (LKR)  Per Capita Energy Use (kWh)  \
# count             47472.000000  47472.000000                 47472.000000
# mean                249.938317   1000.333597                   499.894220
# std                  24.973989     49.966272                    20.074540
# ...
